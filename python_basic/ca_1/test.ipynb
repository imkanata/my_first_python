# %%
# A问题
import numpy as np
A = np.array([[3, 2, 4], [4, 2, 5], [7, 2, 9]])
B = A.T # B是A的转置
C_1 = np.dot(A, B)
C_2 = np.dot(B, A)
print(C_1)
print(C_2)
# Out:
# [[ 29  36  61]
#  [ 36  45  77]
#  [ 61  77 134]]
# [[ 74  28  95]
#  [ 28  12  36]
#  [ 95  36 122]]

# %%
# B问题
import matplotlib.pyplot as plt
time = np.array([2, 23, 17, 11, 9, 14, 21])
score = np.array([10, 17, 12, 4, 13, 18, 11])

plt.xlim([1, 30])
plt.ylim([2, 20])

tick_x = np.arange(0,32,2)
tick_y = np.arange(1,20,3)
plt.xticks(tick_x, fontname='Arial', fontsize=15)
plt.yticks(tick_y, fontname='Arial',fontsize=15)

plt.xlabel('Time(min)',fontname='Arial',fontsize=16)
plt.ylabel('Score',fontname='Arial',fontsize=16)

plt.subplots_adjust(left=0.15, right=0.85, bottom=0.15, top=0.85)

plt.savefig('testB.png',format='png',dpi=300)

plt.scatter(time, score)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("testC.csv")
plt.plot(df['Year'], df['Value'], marker='o')
plt.xticks(df['Year']) # 强制显示每一年
plt.show()
# 用pandas读取csv文件，最好直接在Jupyter新建txt文件然后更改成csv，要不然会有报错
#'utf-8' codec can't decode byte 0xa4 in position 14: invalid start byte

# %%
# D问题
from datetime import date, timedelta

current_date = date(1979, 1, 1) #创造一个具体的开始日期
step = timedelta(days=1) #定义1天的时间跨度
end_date = date(2021, 12, 31) #结束日期

while current_date <= end_date:
    y = current_date.year
    m = current_date.month
    d = current_date.day
    date_str = current_date.strftime("%y%m%d")
    print(date_str)
    current_date +=step
# Out:
# 790101
# 790102
# 790103
# 790104
# 790105
# 790106
# 790107
# 790108
# 790109
# 790110
# 790111
# 790112
# 790113
# 790114
# 790115
# 790116
# 790117
# 790118
# 790119
# 790120
# 790121
# 790122
# 790123
# 790124
# 790125
# 790126
# 790127
# 790128
# 790129
# 790130
# 790131
# 790201
# 790202
# 790203
# 790204
# 790205
# 790206
# 790207
# 790208
# 790209
# 790210
# 790211
# 790212
# 790213
# 790214
# 790215
# 790216
# 790217
# 790218
# 790219
# 790220
# 790221
# 790222
# 790223
# 790224
# 790225
# 790226
# 790227
# 790228
# 790301
# 790302
# 790303
# 790304
# 790305
# 790306
# 790307
# 790308
# 790309
# 790310
# 790311
# 790312
# 790313
# 790314
# 790315
# 790316
# 790317
# 790318
# 790319
# 790320
# 790321
# 790322
# 790323
# 790324
# 790325
# 790326
# 790327
# 790328
# 790329
# 790330
# 790331
# 790401
# 790402
# 790403
# 790404
# 790405
# 790406
# 790407
# 790408
# 790409
# 790410
# 790411
# 790412
# 790413
# 790414
# 790415
# 790416
# 790417
# 790418
# 790419
# 790420
# 790421
# ...
